#   inflating: coca (51).jpeg
#   inflating: coca (53).jpeg
#   inflating: coca (57).jpeg
#   inflating: coca (58).jpeg
#   inflating: coca (59).jpeg
#   inflating: coca (60).jpeg
#   inflating: completas (4).jpg
#   inflating: completas (11).jpeg
#   inflating: completas (13).jpeg
#   inflating: completas (14).jpeg
#   inflating: completas (15).jpeg
#   inflating: completas (18).jpeg
#   inflating: completas (22).jpeg
#   inflating: completas (25).jpeg
#   inflating: completas (27).jpeg
#   inflating: completas (29).jpeg
#   inflating: completas (30).jpeg
#   inflating: completas (31).jpeg
#   inflating: completas (34).jpeg
#   inflating: completas (36).jpeg
#   inflating: completas (39).jpeg
#   inflating: completas (44).jpeg
#   inflating: completas (45).jpeg
#   inflating: completas (46).jpeg
#   inflating: completas (48).jpeg
#   inflating: completas (50).jpeg
#   inflating: completas (55).jpeg
#   inflating: completas (57).jpeg
#   inflating: completas (58).jpeg
#   inflating: completas (59).jpeg
#   inflating: completas (60).jpeg
#   inflating: completas (61).jpeg
#   inflating: completas (62).jpeg
#   inflating: completas (63).jpeg
#   inflating: completas (64).jpeg
#   inflating: completas (65).jpeg
#   inflating: completas (66).jpeg
#   inflating: completas (67).jpeg
#   inflating: completas (70).jpeg
#   inflating: completas (71).jpeg
#   inflating: completas (73).jpeg
#   inflating: completas (74).jpeg
#   inflating: completas (76).jpeg
#   inflating: completas (78).jpeg
#   inflating: completas (79).jpeg
#   inflating: desce (1).jpeg
#   inflating: desce (1).jpg
#   inflating: desce (1).png
#   inflating: desce (2).jpg
#   inflating: desce (2).png
#   inflating: desce (3).jpg
#   inflating: desce (3).png
#   inflating: desce (4).jpeg
#   inflating: desce (4).jpg
#   inflating: desce (4).png
#   inflating: desce (5).jpeg
#   inflating: desce (5).jpg
#   inflating: desce (5).png
#   inflating: desce (6).jpeg
#   inflating: desce (6).jpg
#   inflating: desce (6).png
#   inflating: desce (7).jpeg
#   inflating: desce (8).jpeg
#   inflating: desce (8).jpg
#   inflating: desce (8).png
#   inflating: desce (9).jpeg
#   inflating: desce (9).jpg
#   inflating: desce (9).png
#   inflating: desce (10).jpeg
#   inflating: desce (10).jpg
#   inflating: desce (11).jpg
#   inflating: desce (12).jpeg
#   inflating: desce (12).png
#   inflating: desce (13).jpg
#   inflating: desce (13).png
#   inflating: desce (14).png
#   inflating: desce (15).png
#   inflating: desce (16).jpg
#   inflating: desce (17).jpeg
#   inflating: desce (17).jpg
#   inflating: desce (18).jpeg
#   inflating: desce (19).jpg
#   inflating: desce (20).jpeg
#   inflating: desce (21).jpeg
#   inflating: desce (21).jpg
#   inflating: desce (22).jpeg
#   inflating: desce (24).jpg
#   inflating: desce (25).jpg
#   inflating: desce (26).jpeg
#   inflating: desce (26).jpg
#   inflating: desce (27).jpeg
#   inflating: desce (27).jpg
#   inflating: desce (28).jpg
#   inflating: desce (29).jpeg
#   inflating: desce (29).jpg
#   inflating: desce (30).jpeg
#   inflating: desce (30).jpg
#   inflating: desce (31).jpeg
#   inflating: desce (36).jpeg
#   inflating: desce (39).jpeg
#   inflating: desce (40).jpeg
#   inflating: desce (41).jpeg
#   inflating: desce (42).jpeg
#   inflating: desce (43).jpeg
#   inflating: desce (44).jpeg
#   inflating: desce (45).jpeg
#   inflating: desce (46).jpeg
#   inflating: desce (48).jpeg
#   inflating: desce (49).jpeg
#   inflating: desce (50).jpeg
#   inflating: desce (51).jpeg
#   inflating: desce (53).jpeg
#   inflating: desce (54).jpeg
#   inflating: desce (55).jpeg
#   inflating: desce (57).jpeg
#   inflating: desce (58).jpeg
#   inflating: desce (59).jpeg
#   inflating: desce (66).jpeg
#   inflating: desce (67).jpeg
#   inflating: desce (68).jpeg
#   inflating: desce (72).jpeg
#   inflating: desce (75).jpeg
#   inflating: desce (78).png
#   inflating: desce (79).png
#   inflating: desce (81).jpeg
#   inflating: desce (83).jpeg
#   inflating: desce (84).png
#   inflating: desce (85).jpeg
#   inflating: desce (87).jpeg
#   inflating: desce (88).jpeg
#   inflating: desce (89).jpeg
#   inflating: desce (90).jpeg
#   inflating: desce (92).jpeg
#   inflating: desce (93).jpeg
#   inflating: desce (94).jpeg
#   inflating: desce (95).jpeg
#   inflating: desce (96).jpeg
#   inflating: desce (98).jpeg
#   inflating: desce (100).jpeg
#   inflating: desce (101).jpeg
#   inflating: desce (102).jpeg
#   inflating: desce (103).jpeg
#   inflating: desce (105).jpeg
#   inflating: desce (106).jpeg
#   inflating: desce (107).jpeg
#   inflating: desce (110).jpeg
#   inflating: desce (111).jpeg
#   inflating: desce (113).jpeg
#   inflating: desce (114).jpeg
#   inflating: desce (115).jpeg
#   inflating: desce (116).jpeg
#   inflating: desce (117).jpeg
#   inflating: desce (118).jpeg
#   inflating: desce (119).jpeg
#   inflating: desce (121).jpeg
#   inflating: desce (122).jpeg
#   inflating: desce (123).jpeg
# /content
# /content/latas
# Archive:  /content/latas.zip
#   inflating: latas (153).jpeg
#   inflating: latas (126).jpeg
#   inflating: completas (31).jpeg
#   inflating: completas (45).jpeg
#   inflating: completas (42).jpeg
#   inflating: completas (47).jpeg
#   inflating: latas (145).jpeg
#   inflating: completas (39).jpeg
#   inflating: completas (2).jpeg
#   inflating: latas (137).jpeg
#   inflating: latas (37).jpeg
#   inflating: completas (17).jpeg
#   inflating: latas (165).jpeg
#   inflating: latas (140).jpeg
#   inflating: latas (139).jpeg
#   inflating: latas (77).jpeg
#   inflating: latas (62).jpeg
#   inflating: latas (4).jpeg
#   inflating: latas (43).jpeg
#   inflating: latas (142).jpeg
#   inflating: latas (9).jpeg
#   inflating: completas (44).jpeg
#   inflating: latas (45).jpeg
#   inflating: latas (82).jpeg
#   inflating: completas (36).jpeg
#   inflating: latas (5).jpeg
#   inflating: completas (19).jpeg
#   inflating: latas (31).jpeg
#   inflating: completas (14).jpeg
#   inflating: latas (71).jpeg
#   inflating: latas (32).jpeg
#   inflating: latas (130).jpeg
#   inflating: latas (68).jpeg
#   inflating: latas (69).jpeg
#   inflating: latas (127).jpeg
#   inflating: latas (56).jpeg
#   inflating: latas (57).jpeg
#   inflating: latas (141).jpeg
#   inflating: latas (6).jpeg
#   inflating: completas (40).jpeg
#   inflating: latas (53).jpeg
#   inflating: latas (67).jpeg
#   inflating: completas (41).jpg
#   inflating: latas (55).jpeg
#   inflating: completas (24).jpeg
#   inflating: latas (109).jpeg
#   inflating: latas (161).jpeg
#   inflating: latas (42).jpeg
#   inflating: latas (92).jpeg
#   inflating: latas (134).jpeg
#   inflating: latas (3).jpeg
#   inflating: completas (27).jpeg
#   inflating: completas (23).jpeg
#   inflating: latas (164).jpeg
#   inflating: completas (30).jpeg
#   inflating: completas (5).jpeg
#   inflating: completas (37).jpeg
#   inflating: latas (17).jpeg
#   inflating: latas (63).jpeg
#   inflating: latas (49).jpeg
#   inflating: completas (5).png
#   inflating: latas (50).jpeg
#   inflating: latas (51).jpg
#   inflating: completas (34).jpeg
#   inflating: completas (32).jpeg
#   inflating: latas (90).jpeg
#   inflating: latas (65).jpeg
#   inflating: latas (107).jpeg
#   inflating: latas (25).jpeg
#   inflating: completas (15).jpeg
#   inflating: completas (6).jpeg
#   inflating: completas (25).jpeg
#   inflating: latas (148).jpeg
#   inflating: latas (136).jpeg
#   inflating: latas (79).jpeg
#   inflating: completas (49).jpeg
#   inflating: latas (101).jpeg
#   inflating: latas (135).jpeg
#   inflating: completas (38).jpeg
#   inflating: latas (157).jpeg
#   inflating: latas (99).jpeg
#   inflating: latas (111).jpeg
#   inflating: completas (6).png
#   inflating: latas (52).jpeg
#   inflating: latas (133).jpeg
#   inflating: completas (13).jpeg
#   inflating: latas (103).jpeg
#   inflating: latas (40).jpeg
#   inflating: completas (9).jpeg
#   inflating: latas (91).jpeg
#   inflating: completas (18).jpeg
#   inflating: completas (10).jpeg
#   inflating: latas (14).jpeg
#   inflating: completas (11).jpeg
#   inflating: completas (3).jpeg
#   inflating: latas (118).jpeg
#   inflating: latas (2).jpeg
#   inflating: latas (123).jpeg
#   inflating: completas (41).jpeg
#   inflating: latas (106).jpeg
#   inflating: latas (93).jpeg
#   inflating: latas (35).jpg
#   inflating: latas (159).jpeg
#   inflating: latas (158).jpeg
#   inflating: latas (19).jpeg
#   inflating: completas (43).jpeg
#   inflating: latas (122).jpeg
#   inflating: latas (74).jpeg
#   inflating: latas (162).jpeg
#   inflating: completas (26).jpeg
#   inflating: latas (61).jpeg
#   inflating: latas (124).jpeg
#   inflating: latas (120).jpeg
#   inflating: latas (88).jpeg
#   inflating: latas (11).jpeg
#   inflating: latas (33).jpeg
#   inflating: latas (86).jpeg
#   inflating: latas (132).jpeg
#   inflating: completas (28).jpeg
#   inflating: completas (1).jpg
#   inflating: completas (48).jpg
#   inflating: completas (47).jpg
#   inflating: latas (66).jpeg
#   inflating: latas (14).png
#   inflating: latas (128).jpeg
#   inflating: latas (116).jpeg
#   inflating: latas (117).jpeg
#   inflating: latas (60).jpeg
#   inflating: completas (21).jpeg
#   inflating: latas (61).jpg
#   inflating: latas (102).jpeg
#   inflating: completas (48).jpeg
#   inflating: latas (154).jpeg
#   inflating: latas (150).jpeg
#   inflating: completas (29).jpeg
#   inflating: latas (46).jpeg
#   inflating: latas (45).jpg
#   inflating: latas (35).jpeg
#   inflating: latas (22).jpeg
#   inflating: completas (12).jpeg
#   inflating: latas (39).jpeg
#   inflating: latas (28).jpeg
#   inflating: latas (12).jpeg
#   inflating: latas (18).jpeg
#   inflating: completas (20).jpeg
#   inflating: latas (84).jpeg
#   inflating: latas (151).jpeg
#   inflating: latas (156).jpeg
#   inflating: latas (114).jpeg
#   inflating: completas (33).jpeg
#   inflating: completas (27).jpg
#   inflating: latas (34).jpg
#   inflating: latas (36).jpeg
#   inflating: latas (80).jpeg
#   inflating: latas (163).jpeg
#   inflating: latas (147).jpeg
#   inflating: latas (149).jpeg
#   inflating: latas (13).jpeg
#   inflating: completas (4).jpeg
#   inflating: latas (95).jpeg
#   inflating: latas (155).jpeg
#   inflating: latas (44).jpg
#   inflating: latas (15).jpeg
#   inflating: latas (48).jpg
#   inflating: completas (35).jpeg
#   inflating: latas (23).jpg
#   inflating: completas (22).jpeg
#   inflating: completas (16).jpeg
#   inflating: latas (172).jpeg
#   inflating: latas (4).jpg
#   inflating: completas (40).jpg
#   inflating: completas (53).jpg
#   inflating: latas (37).jpg
#   inflating: completas (26).jpg
#   inflating: completas (25).jpg
#   inflating: completas (34).jpg
#   inflating: latas (27).jpg
#   inflating: completas (32).jpg
#   inflating: latas (11).jpg
#   inflating: latas (41).jpg
#   inflating: latas (3).jpg
#   inflating: completas (54).jpg
#   inflating: completas (4).jpg
#   inflating: completas (39).jpg
#   inflating: completas (35).jpg
#   inflating: completas (18).jpg
#   inflating: completas (36).jpg
#   inflating: latas (46).jpg
#   inflating: latas (47).jpg
#   inflating: latas (5).jpg
#   inflating: completas (31).jpg
#   inflating: completas (3).jpg
#   inflating: latas (171).jpeg
#   inflating: latas (20).jpg
#   inflating: completas (55).jpg
#   inflating: latas (25).jpg
#   inflating: latas (21).jpg
#   inflating: latas (6).jpg
#   inflating: completas (11).jpg
#   inflating: completas (1).png
#   inflating: latas (36).jpg
#   inflating: completas (52).jpg
#   inflating: completas (51).jpg
#   inflating: latas (50).jpg
#   inflating: latas (18).jpg
#   inflating: latas (22).jpg
#   inflating: latas (12).jpg
#   inflating: completas (12).jpg
#   inflating: latas (8).jpg
#   inflating: completas (13).jpg
#   inflating: completas (23).jpg
#   inflating: completas (5).jpg
#   inflating: completas (14).jpg
#   inflating: latas (54).jpg
#   inflating: completas (17).jpg
#   inflating: completas (44).jpg
#   inflating: latas (62).jpg
#   inflating: completas (16).jpg
#   inflating: completas (15).jpg
#   inflating: latas (15).jpg
#   inflating: latas (59).jpg
#   inflating: latas (19).jpg
#   inflating: latas (64).jpg
#   inflating: completas (18).png
#   inflating: completas (2).jpg
#   inflating: latas (56).jpg
#   inflating: latas (55).jpg
#   inflating: completas (46).jpg
#   inflating: latas (31).jpg
#   inflating: completas (30).jpg
#   inflating: completas (10).jpg
#   inflating: completas (33).jpg
#   inflating: completas (42).jpg
#   inflating: latas (53).jpg
#   inflating: completas (43).jpg
#   inflating: completas (37).jpg
#   inflating: latas (13).jpg
#   inflating: latas (14).jpg
#   inflating: completas (1).jpeg
#   inflating: completas (11).png
#   inflating: latas (30).jpg
#   inflating: completas (15).png
#   inflating: completas (22).jpg
#   inflating: latas (58).jpg
#   inflating: completas (6).jpg
#   inflating: latas (40).jpg
#   inflating: latas (29).jpg
#   inflating: completas (28).jpg
#   inflating: latas (10).jpg
#   inflating: completas (8).jpg
#   inflating: completas (16).png
#   inflating: latas (60).jpg
#   inflating: completas (49).jpg
#   inflating: latas (28).jpg
#   inflating: completas (10).png
#   inflating: latas (33).jpg
#   inflating: latas (49).jpg
#   inflating: latas (17).jpg
#   inflating: completas (17).png
#   inflating: latas (1).jpg
#   inflating: latas (38).jpg
#   inflating: completas (50).jpg
#   inflating: latas (9).jpg
#   inflating: completas (9).jpg
#   inflating: completas (29).jpg
#   inflating: completas (38).jpg
#   inflating: latas (24).jpg
#   inflating: completas (50).jpeg
#   inflating: completas (4).png
#   inflating: latas (32).jpg
#   inflating: latas (2).jpg
#   inflating: latas (39).jpg
#   inflating: completas (45).jpg
#   inflating: completas (21).jpg
#   inflating: latas (42).jpg
#   inflating: latas (2).png
#   inflating: latas (3).png
#   inflating: completas (7).jpeg
#   inflating: completas (8).png
#   inflating: latas (110).jpeg
#   inflating: latas (21).jpeg
#   inflating: latas (1).jpeg
# /content
# /content/vasos
# Archive:  /content/Vasos.zip
#   inflating: images - 2025-05-07T202028.747.jpeg
#   inflating: images - 2025-05-07T202028.748.jpeg
#   inflating: images - 2025-05-07T202028.749.jpeg
#   inflating: images - 2025-05-07T202028.990.jpeg
#   inflating: images - 2025-05-07T202029.036.jpeg
#   inflating: images - 2025-05-07T202029.037.jpeg
#   inflating: images - 2025-05-07T202029.040.jpeg
#   inflating: images - 2025-05-07T202029.046.jpeg
#   inflating: images - 2025-05-07T202029.051.jpeg
#   inflating: images - 2025-05-07T202029.052.jpeg
#   inflating: images - 2025-05-07T202029.056.jpeg
#   inflating: images - 2025-05-07T202029.057.jpeg
#   inflating: images - 2025-05-07T202029.058.jpeg
#   inflating: images (1).jpeg
#   inflating: images (2).jpeg
#   inflating: images (3).jpeg
#   inflating: images (4).jpeg
#   inflating: images (5).jpeg
#   inflating: images (6).jpeg
#   inflating: images (7).jpeg
#   inflating: images (9).jpeg
#   inflating: images (10).jpeg
#   inflating: images (12).jpeg
#   inflating: images (13).jpeg
#   inflating: images (14).jpeg
#   inflating: images (15).jpeg
#   inflating: images (16).jpeg
#   inflating: images (17).jpeg
#   inflating: images (18).jpeg
#   inflating: images (19).jpeg
#   inflating: images (20).jpeg
#   inflating: images (21).jpeg
#   inflating: images (22).jpeg
#   inflating: images (23).jpeg
#   inflating: images (24).jpeg
#   inflating: images (25).jpeg
#   inflating: images (26).jpeg
#   inflating: images (27).jpeg
#   inflating: images (28).jpeg
#   inflating: images (29).jpeg
#   inflating: images (30).jpeg
#   inflating: images (31).jpeg
#   inflating: images (32).jpeg
#   inflating: images (33).jpeg
#   inflating: images (34).jpeg
#   inflating: images (35).jpeg
#   inflating: images (36).jpeg
#   inflating: images (37).jpeg
#   inflating: images (38).jpeg
#   inflating: images (39).jpeg
#   inflating: images (40).jpeg
#   inflating: images (41).jpeg
#   inflating: images (43).jpeg
#   inflating: images (44).jpeg
#   inflating: images (45).jpeg
#   inflating: images (46).jpeg
#   inflating: images (47).jpeg
#   inflating: images (48).jpeg
#   inflating: images (49).jpeg
#   inflating: images (50).jpeg
#   inflating: images (51).jpeg
#   inflating: images (52).jpeg
#   inflating: images (53).jpeg
#   inflating: Z1 (90).jpeg
#   inflating: Z1 (92).jpeg
#   inflating: Z1 (94).jpeg
#   inflating: Z1 (95).jpeg
#   inflating: Z1 (96).jpeg
#   inflating: Z1 (100).jpeg
#   inflating: Z1 (101).jpeg
#   inflating: Z1 (102).jpeg
#   inflating: Z1 (105).jpeg
#   inflating: Z1 (108).jpeg
#   inflating: Z1 (110).jpeg
#   inflating: Z1 (114).jpeg
#   inflating: Z2 (2).jpg
#   inflating: Z2 (3).jpeg
#   inflating: Z2 (3).jpg
#   inflating: Z2 (4).jpeg
#   inflating: Z2 (4).jpg
#   inflating: Z2 (5).jpg
#   inflating: Z2 (7).jpeg
#   inflating: Z2 (7).jpg
#   inflating: Z2 (9).jpeg
#   inflating: Z2 (9).jpg
#   inflating: Z2 (10).jpeg
#   inflating: Z2 (11).jpeg
#   inflating: Z2 (11).jpg
#   inflating: Z2 (12).jpeg
#   inflating: Z2 (12).jpg
#   inflating: Z2 (13).jpeg
#   inflating: Z2 (13).jpg
#   inflating: Z2 (14).jpeg
#   inflating: Z2 (14).jpg
#   inflating: Z2 (15).jpeg
#   inflating: Z2 (16).jpeg
#   inflating: Z2 (17).jpeg
#   inflating: Z2 (19).jpeg
#   inflating: Z2 (20).jpeg
#   inflating: Z2 (21).jpeg
#   inflating: Z2 (23).jpeg
#   inflating: Z2 (24).jpeg
#   inflating: Z2 (27).jpeg
#   inflating: Z2 (35).jpeg
#   inflating: Z2 (36).jpeg
#   inflating: Z2 (37).jpeg
#   inflating: Z2 (39).jpeg
#   inflating: Z2 (41).jpeg
#   inflating: Z2 (42).jpeg
#   inflating: Z2 (43).jpeg
#   inflating: Z2 (47).jpeg
#   inflating: Z2 (49).jpeg
#   inflating: Z2 (51).jpeg
#   inflating: Z2 (58).jpeg
#   inflating: Z2 (60).jpeg
#   inflating: Z2 (65).jpeg
#   inflating: Z2 (67).jpeg
#   inflating: Z2 (71).jpeg
#   inflating: Z2 (72).jpeg
#   inflating: Z2 (74).jpeg
#   inflating: Z2 (76).jpeg
#   inflating: Z2 (78).jpeg
#   inflating: Z2 (79).jpeg
#   inflating: Z2 (80).jpeg
#   inflating: Z2 (81).jpeg
#   inflating: Z2 (82).jpeg
#   inflating: Z2 (83).jpeg
#   inflating: Z2 (84).jpeg
#   inflating: Z2 (85).jpeg
#   inflating: Z2 (88).jpeg
#   inflating: Z2 (91).jpeg
#   inflating: Z2 (95).jpeg
#   inflating: Z2 (97).jpeg
#   inflating: Z2 (99).jpeg
#   inflating: Z2 (100).jpeg
#   inflating: images - 2025-05-07T202028.745.jpeg
#   inflating: images - 2025-05-07T202028.746.jpeg
# /content

# %%
# !rm -rf /content/botellas.zip
# !rm -rf /content/latas.zip
# !rm -rf /content/Vasos.zip

# %%
# !ls /content/botellas | wc -l
# !ls /content/latas | wc -l
# !ls /content/vasos | wc -l
# Out:
# 331
# 282
# 232

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/latas'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  img = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(img)

plt.show()

# %%
# !mkdir dataset
# !mkdir dataset/botellas
# !mkdir dataset/latas
# !mkdir dataset/vasos

# %%
import shutil
carpeta_fuente = '/content/botellas'
carpeta_destino = '/content/dataset/botellas'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 232:
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
import shutil
carpeta_fuente = '/content/latas'
carpeta_destino = '/content/dataset/latas'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 232:
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
import shutil
carpeta_fuente = '/content/vasos'
carpeta_destino = '/content/dataset/vasos'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 232:
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
# !ls /content/dataset/botellas | wc -l
# !ls /content/dataset/latas | wc -l
# !ls /content/dataset/vasos | wc -l
# Out:
# 232
# 232
# 232

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split = 0.2
)

data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size = (224, 224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size = (224, 224),
                                                     batch_size=32, shuffle=True, subset='validation')

for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 558 images belonging to 3 classes.
# Found 138 images belonging to 3 classes.

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
mobilenetv2.trainable = False

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

mobilenetv2.trainable = False


model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(224,224,3)),
    tf.keras.layers.Lambda(lambda x: mobilenetv2(x)),
    tf.keras.layers.Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                 │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         3,843 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,843 (15.01 KB)
#  Trainable params: 3,843 (15.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
EPOCAS = 50

historial = model.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
#  5/18 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.3614 - loss: 1.2631
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.4748 - loss: 1.0638 - val_accuracy: 0.6522 - val_loss: 0.7730
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.8030 - loss: 0.5148 - val_accuracy: 0.7391 - val_loss: 0.6100
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8882 - loss: 0.3598 - val_accuracy: 0.7609 - val_loss: 0.6055
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8454 - loss: 0.3720 - val_accuracy: 0.7971 - val_loss: 0.4509
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8917 - loss: 0.3194 - val_accuracy: 0.8188 - val_loss: 0.5014
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step
50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9568 - loss: 0.1287 - val_accuracy: 0.8551 - val_loss: 0.3995
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9571 - loss: 0.1598 - val_accuracy: 0.8478 - val_loss: 0.4708
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9607 - loss: 0.1171 - val_accuracy: 0.8841 - val_loss: 0.4187
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9593 - loss: 0.1168 - val_accuracy: 0.8406 - val_loss: 0.4513
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9664 - loss: 0.1096 - val_accuracy: 0.8261 - val_loss: 0.4875
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9346 - loss: 0.1709 - val_accuracy: 0.8913 - val_loss: 0.4013
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9607 - loss: 0.1300 - val_accuracy: 0.8116 - val_loss: 0.4510
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9623 - loss: 0.1224 - val_accuracy: 0.7971 - val_loss: 0.4933
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9602 - loss: 0.1276 - val_accuracy: 0.8188 - val_loss: 0.3722
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9563 - loss: 0.1279 - val_accuracy: 0.8333 - val_loss: 0.4810
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9673 - loss: 0.1148 - val_accuracy: 0.8333 - val_loss: 0.4391
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9719 - loss: 0.1155 - val_accuracy: 0.8261 - val_loss: 0.4578
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9640 - loss: 0.0999 - val_accuracy: 0.8261 - val_loss: 0.4407
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9482 - loss: 0.1493 - val_accuracy: 0.8551 - val_loss: 0.3781
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9729 - loss: 0.1125 - val_accuracy: 0.8116 - val_loss: 0.5137
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9676 - loss: 0.0973 - val_accuracy: 0.8406 - val_loss: 0.5780
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.9633 - loss: 0.1075 - val_accuracy: 0.8116 - val_loss: 0.5101

# %%
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(50)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.ylim([0,1])
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.savefig("Precision .png")
plt.show()

# %%
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = model.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1)

# %%
url = 'https://www.omipack.com/wp-content/uploads/2022/06/vaso-carton-kraft-120ml-4oz.jpg'
prediccion = categorizar(url)
print(prediccion)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 2
